# %%
import pandas as pd
import numpy as np
dt=pd.read_csv("practical2.csv")

# %%
dt
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0           62             81             60               87            2019
# 1           78             94             68               79            2019
# 2           68             92             70               80            2021
# 3           72             78             66               79            2019
# 4           75             91             75               81            2019
# 5           80             77             78               97            2020
# 6           77             76             72               86            2021
# 7           61             82             61               91            2020
# 8           79             91             80               82            2021
# 9           63             90             69               97            2021
# 10          71             83             64              100            2020
# ...

# %%
dt['gender']=dt['gender'].map({'male':0,'female':1})

# %%
dt
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0           62             81             60               87            2019
# 1           78             94             68               79            2019
# 2           68             92             70               80            2021
# 3           72             78             66               79            2019
# 4           75             91             75               81            2019
# 5           80             77             78               97            2020
# 6           77             76             72               86            2021
# 7           61             82             61               91            2020
# 8           79             91             80               82            2021
# 9           63             90             69               97            2021
# 10          71             83             64              100            2020
# ...

# %%
m=v_dt['math_score'].mean()
dt['math_score'].fillna(value=m_v,inplace=True)
dt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 m=v_dt['math_score'].mean()
#       2 dt['math_score'].fillna(value=m_v,inplace=True)
#       3 dt
#
# NameError: name 'v_dt' is not defined
