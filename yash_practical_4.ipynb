# %%
import pandas as pd
dt=pd.read_csv('BigBasket.csv')

# %%
dt
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
a,b=dt.shape
print("number of rows in given dataset",a)
print("number of column in dataset",b)
# Out:
# number of rows in given dataset 27555
# number of column in dataset 10

# %%
dt.head(3)
# Out:
#    index                                 product                category  \
# 0      1  Garlic Oil - Vegetarian Capsule 500 mg        Beauty & Hygiene
# 1      2                   Water Bottle - Orange  Kitchen, Garden & Pets
# 2      3          Brass Angle Deep - Plain, No.2    Cleaning & Household
#
#             sub_category              brand  sale_price  market_price  \
# 0              Hair Care  Sri Sri Ayurveda        220.0         220.0
# 1  Storage & Accessories         Mastercook       180.0         180.0
# 2            Pooja Needs                Trm       119.0         250.0
#
#                      type  rating  \
# 0        Hair Oil & Serum     4.1
# 1  Water & Fridge Bottles     2.3
# 2         Lamp & Lamp Oil     3.4
#
#                                          description
# 0  This Product contains Garlic Oil that is known...
# 1  Each product is microwave safe (without lid), ...
# 2  A perfect gift for all occasions, be it your m...

# %%
dt.tail(5)
# Out:
#        index                                     product  \
# 27550  27551  Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                    Rosemary
# 27552  27553                Peri-Peri Sweet Potato Chips
# 27553  27554                   Green Tea - Pure Original
# 27554  27555              United Dreams Go Far Deodorant
#
#                    category              sub_category  \
# 27550      Beauty & Hygiene         Fragrances & Deos
# 27551  Gourmet & World Food    Cooking & Baking Needs
# 27552  Gourmet & World Food  Snacks, Dry Fruits, Nuts
# 27553             Beverages                       Tea
# 27554      Beauty & Hygiene            Men's Grooming
#
#                             brand  sale_price  market_price  \
# 27550                      Layerr      199.20         249.0
# 27551                    Puramate       67.50          75.0
# 27552                      FabBox      200.00         200.0
# ...

# %%
dt.tail(10)
# Out:
#        index                                          product  \
# 27545  27546  Toilet Cleaning Brush - Round With Holder (Big)
# 27546  27547                    Organic Powder - Garam Masala
# 27547  27548                                  Powder - Baking
# 27548  27549                      Apple Cider Vinegar Shampoo
# 27549  27550                             Papad - Garlic Disco
# 27550  27551       Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                         Rosemary
# 27552  27553                     Peri-Peri Sweet Potato Chips
# 27553  27554                        Green Tea - Pure Original
# 27554  27555                   United Dreams Go Far Deodorant
#
#                        category              sub_category  \
# 27545      Cleaning & Household    Mops, Brushes & Scrubs
# 27546  Foodgrains, Oil & Masala           Organic Staples
# 27547    Snacks & Branded Foods       Ready To Cook & Eat
# ...

# %%
dt['product']
# Out:
# 0                   Garlic Oil - Vegetarian Capsule 500 mg
# 1                                    Water Bottle - Orange
# 2                           Brass Angle Deep - Plain, No.2
# 3        Cereal Flip Lid Container/Storage Jar - Assort...
# 4                       Creme Soft Soap - For Hands & Body
#                                ...
# 27550           Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                             Rosemary
# 27552                         Peri-Peri Sweet Potato Chips
# 27553                            Green Tea - Pure Original
# 27554                       United Dreams Go Far Deodorant
# Name: product, Length: 27555, dtype: object

# %%
dt.iloc[:,1]
# Out:
# 0                   Garlic Oil - Vegetarian Capsule 500 mg
# 1                                    Water Bottle - Orange
# 2                           Brass Angle Deep - Plain, No.2
# 3        Cereal Flip Lid Container/Storage Jar - Assort...
# 4                       Creme Soft Soap - For Hands & Body
#                                ...
# 27550           Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                             Rosemary
# 27552                         Peri-Peri Sweet Potato Chips
# 27553                            Green Tea - Pure Original
# 27554                       United Dreams Go Far Deodorant
# Name: product, Length: 27555, dtype: object

# %%
dt.iloc[:,1:3]
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category
# 0            Beauty & Hygiene
# 1      Kitchen, Garden & Pets
# 2        Cleaning & Household
# 3        Cleaning & Household
# 4            Beauty & Hygiene
# ...                       ...
# 27550        Beauty & Hygiene
# ...

# %%
dt[['product','sale_price']]
# Out:
#                                                  product  sale_price
# 0                 Garlic Oil - Vegetarian Capsule 500 mg      220.00
# 1                                  Water Bottle - Orange      180.00
# 2                         Brass Angle Deep - Plain, No.2      119.00
# 3      Cereal Flip Lid Container/Storage Jar - Assort...      149.00
# 4                     Creme Soft Soap - For Hands & Body      162.00
# ...                                                  ...         ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic      199.20
# 27551                                           Rosemary       67.50
# 27552                       Peri-Peri Sweet Potato Chips      200.00
# 27553                          Green Tea - Pure Original      396.00
# 27554                     United Dreams Go Far Deodorant      214.53
#
# [27555 rows x 2 columns]

# %%
dt['sale_price'].sum()
# Out:
# 8886895.53

# %%
dt.dtypes
# Out:
# index             int64
# product          object
# category         object
# sub_category     object
# brand            object
# sale_price      float64
# market_price    float64
# type             object
# rating          float64
# description      object
# dtype: object

# %%
dt.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# dtype: int64

# %%
dt.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# dtype: int64

# %%
dt.isnull().min()
# Out:
# index           False
# product         False
# category        False
# sub_category    False
# brand           False
# sale_price      False
# market_price    False
# type            False
# rating          False
# description     False
# dtype: bool

# %%
dt.dtypes
# Out:
# index             int64
# product          object
# category         object
# sub_category     object
# brand            object
# sale_price      float64
# market_price    float64
# type             object
# rating          float64
# description      object
# dtype: object

# %%
dt.describe()
# Out:
#              index    sale_price  market_price        rating
# count  27555.00000  27555.000000  27555.000000  18929.000000
# mean   13778.00000    322.514808    382.056664      3.943410
# std     7954.58767    486.263116    581.730717      0.739063
# min        1.00000      2.450000      3.000000      1.000000
# 25%     6889.50000     95.000000    100.000000      3.700000
# 50%    13778.00000    190.000000    220.000000      4.100000
# 75%    20666.50000    359.000000    425.000000      4.300000
# max    27555.00000  12500.000000  12500.000000      5.000000

# %%
dt.sale_price.min()
# Out:
# 2.45

# %%
dt.isnull().max()
# Out:
# index           False
# product          True
# category        False
# sub_category    False
# brand            True
# sale_price      False
# market_price    False
# type            False
# rating           True
# description      True
# dtype: bool

# %%
dt.isnull().mean()
# Out:
# index           0.000000
# product         0.000036
# category        0.000000
# sub_category    0.000000
# brand           0.000036
# sale_price      0.000000
# market_price    0.000000
# type            0.000000
# rating          0.313047
# description     0.004173
# dtype: float64

# %%
dt.isnull().std()
# Out:
# index           0.000000
# product         0.006024
# category        0.000000
# sub_category    0.000000
# brand           0.006024
# sale_price      0.000000
# market_price    0.000000
# type            0.000000
# rating          0.463742
# description     0.064469
# dtype: float64

# %%
dt.columns
# Out:
# Index(['index', 'product', 'category', 'sub_category', 'brand', 'sale_price',
#        'market_price', 'type', 'rating', 'description'],
#       dtype='object')

# %%
dt.sale_price.max()
# Out:
# 12500.0

# %%
dt.sale_price.std()
# Out:
# 486.26311554286923

# %%
dt.shape
# Out:
# (27555, 10)

# %%
row_2 = dt.iloc[1] 
print(row_2)
# Out:
# index                                                           2
# product                                     Water Bottle - Orange
# category                                   Kitchen, Garden & Pets
# sub_category                                Storage & Accessories
# brand                                                  Mastercook
# sale_price                                                  180.0
# market_price                                                180.0
# type                                       Water & Fridge Bottles
# rating                                                        2.3
# description     Each product is microwave safe (without lid), ...
# Name: 1, dtype: object

# %%
dt.market_price.max()
# Out:
# 12500.0

# %%
dt.market_price.min()
# Out:
# 3.0

# %%
dt.market_price.sum()
# Out:
# 10527571.39

# %%
dt.market_price.std()
# Out:
# 581.7307174034938

# %%
dt.index
# Out:
# RangeIndex(start=0, stop=27555, step=1)

# %%
dt.index.min()
# Out:
# 0

# %%
dt.index.max()
# Out:
# 27554

# %%
st=pd.read_csv('practical_4.csv')

# %%
st
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join  \
# 0           69             95             60               78       2020
# 1           61             93             61               92       2018
# 2           74             85             66               89       2019
# 3           75             80             78               82       2020
# 4           71             91             79               80       2020
# 5           73             82             70               75       2021
# 6           79             83             65               79       2019
# 7           75             92             66               77       2021
# 8           71             86             64               88       2019
# 9           77             91             77               99       2020
# 10          75             87             74               79       2019
# 11          71             95             71               93       2019
# ...

# %%
st.isnull().sum()
# Out:
# math_score         0
# reading_score      0
# writing_score      0
# placement_score    0
# club_join          0
# placementcount     0
# dtype: int64

# %%
st.fillna(999,axis=1)
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join  \
# 0           69             95             60               78       2020
# 1           61             93             61               92       2018
# 2           74             85             66               89       2019
# 3           75             80             78               82       2020
# 4           71             91             79               80       2020
# 5           73             82             70               75       2021
# 6           79             83             65               79       2019
# 7           75             92             66               77       2021
# 8           71             86             64               88       2019
# 9           77             91             77               99       2020
# 10          75             87             74               79       2019
# 11          71             95             71               93       2019
# ...

# %%
st.columns
# Out:
# Index(['math_score', 'reading_score', 'writing_score', 'placement_score',
#        'club_join', 'placementcount'],
#       dtype='object')

# %%
st.index
# Out:
# RangeIndex(start=0, stop=30, step=1)
